# %% [markdown]
# Create a program to read a JSON file, convert it into a DataFrame, and export it to a CSV

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create DataFrame from JSON

# %%
json_file="data.json"
df = pd.read_json(json_file)
df
# Out:
#    index     name  age  salary
# 0      0    alice   25   50000
# 1      1      bob   30   60000
# 2      2  charlie   35   70000

# %% [markdown]
# Export to CSV

# %%
json_file="data.json"
df = pd.read_json(json_file)
df
# Out:
#    index     name  age  salary
# 0      0    alice   25   50000
# 1      1      bob   30   60000
# 2      2  charlie   35   70000

# %%
csv_file=df.to_csv('data.csv')
csv_file

# %% [markdown]
# Print confirmation

# %%
print('csv file is created successfully')
# Out:
# csv file is created successfully
